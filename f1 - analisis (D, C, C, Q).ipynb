# %%
import requests
import json
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
#Diccionario conductores
drivers ={'driverId':[], 'url':[], 'givenName':[], 'familyName':[], 'dateOfBirth':[], 'nationality':[]}

# %%
for year in list(range(2010, 2023)):
    url = "https://ergast.com/api/f1/{}/drivers.json"
    response = requests.get(url.format(year))
    content = json.loads(response.content)
    
    for item in content['MRData']['DriverTable']['Drivers']:
        drivers['driverId'].append(item['driverId'])
        drivers['url'].append(item['url'])
        drivers['givenName'].append(item['givenName'])
        drivers['familyName'].append(item['familyName'])
        drivers['dateOfBirth'].append(item['dateOfBirth'])
        drivers['nationality'].append(item['nationality'])

# %%
pd.DataFrame(drivers)
# Out:
#            driverId                                                url  \
# 0       alguersuari     http://en.wikipedia.org/wiki/Jaime_Alguersuari
# 1            alonso       http://en.wikipedia.org/wiki/Fernando_Alonso
# 2       barrichello    http://en.wikipedia.org/wiki/Rubens_Barrichello
# 3             buemi  http://en.wikipedia.org/wiki/S%C3%A9bastien_Buemi
# 4            button         http://en.wikipedia.org/wiki/Jenson_Button
# ..              ...                                                ...
# 299          stroll          http://en.wikipedia.org/wiki/Lance_Stroll
# 300         tsunoda          http://en.wikipedia.org/wiki/Yuki_Tsunoda
# 301  max_verstappen        http://en.wikipedia.org/wiki/Max_Verstappen
# 302          vettel      http://en.wikipedia.org/wiki/Sebastian_Vettel
# 303            zhou           http://en.wikipedia.org/wiki/Guanyu_Zhou
#
#      givenName   familyName dateOfBirth nationality
# 0        Jaime  Alguersuari  1990-03-23     Spanish
# 1     Fernando       Alonso  1981-07-29     Spanish
# 2       Rubens  Barrichello  1972-05-23   Brazilian
# 3    Sébastien        Buemi  1988-10-31       Swiss
# 4       Jenson       Button  1980-01-19     British
# ..         ...          ...         ...         ...
# 299      Lance       Stroll  1998-10-29    Canadian
# 300       Yuki      Tsunoda  2000-05-11    Japanese
# 301        Max   Verstappen  1997-09-30       Dutch
# 302  Sebastian       Vettel  1987-07-03      German
# 303     Guanyu         Zhou  1999-05-30     Chinese
#
# [304 rows x 6 columns]

# %%
pd.DataFrame(drivers).to_csv('drivers.csv', index = False)

# %%
#Diccionario constructores
constructors = {'constructorId':[], 'url':[], 'name':[], 'nationality':[]}

# %%
for year in list(range(2010, 2023)):
    url = "http://ergast.com/api/f1/{}/constructors.json"
    response = requests.get(url.format(year))
    content = json.loads(response.content)
    
    for item in content['MRData']['ConstructorTable']['Constructors']:
        constructors['constructorId'].append(item['constructorId'])
        constructors['url'].append(item['url'])
        constructors['name'].append(item['name'])
        constructors['nationality'].append(item['nationality'])

# %%
pd.DataFrame(constructors)
# Out:
#     constructorId                                                url  \
# 0         ferrari      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 1     force_india  http://en.wikipedia.org/wiki/Racing_Point_Forc...
# 2             hrt       http://en.wikipedia.org/wiki/Hispania_Racing
# 3    lotus_racing          http://en.wikipedia.org/wiki/Lotus_Racing
# 4         mclaren               http://en.wikipedia.org/wiki/McLaren
# ..            ...                                                ...
# 134          haas          http://en.wikipedia.org/wiki/Haas_F1_Team
# 135       mclaren               http://en.wikipedia.org/wiki/McLaren
# 136      mercedes  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...
# 137      red_bull       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 138      williams  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
#
#              name nationality
# 0         Ferrari     Italian
# 1     Force India      Indian
# 2             HRT     Spanish
# 3           Lotus   Malaysian
# 4         McLaren     British
# ..            ...         ...
# 134  Haas F1 Team    American
# 135       McLaren     British
# 136      Mercedes      German
# 137      Red Bull    Austrian
# 138      Williams     British
#
# [139 rows x 4 columns]

# %%
pd.DataFrame(constructors).to_csv('constructors.csv', index = False)

# %%
#Diccionario circuitos
circuits = {'circuitId':[], 'url':[], 'circuitName':[], 'lat':[], 'long':[], 'locality':[], 'country':[]}

# %%
for year in list(range(2010, 2023)):
    url = "http://ergast.com/api/f1/{}/circuits.json"
    response = requests.get(url.format(year))
    content = json.loads(response.content)
    
    for item in content['MRData']['CircuitTable']['Circuits']:
        circuits['circuitId'].append(item['circuitId'])
        circuits['url'].append(item['url'])
        circuits['circuitName'].append(item['circuitName'])
        circuits['lat'].append(float(item['Location']['lat']))
        circuits['long'].append(float(item['Location']['long']))
        circuits['locality'].append(item['Location']['locality'])
        circuits['country'].append(item['Location']['country'])

# %%
pd.DataFrame(circuits)
# Out:
#           circuitId                                                url  \
# 0       albert_park  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1           bahrain  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 2         catalunya  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# 3    hockenheimring        http://en.wikipedia.org/wiki/Hockenheimring
# 4       hungaroring           http://en.wikipedia.org/wiki/Hungaroring
# ..              ...                                                ...
# 250             spa  http://en.wikipedia.org/wiki/Circuit_de_Spa-Fr...
# 251          suzuka        http://en.wikipedia.org/wiki/Suzuka_Circuit
# 252      villeneuve  http://en.wikipedia.org/wiki/Circuit_Gilles_Vi...
# 253      yas_marina    http://en.wikipedia.org/wiki/Yas_Marina_Circuit
# 254       zandvoort     http://en.wikipedia.org/wiki/Circuit_Zandvoort
#
#                         circuitName      lat       long    locality  \
# 0    Albert Park Grand Prix Circuit -37.8497  144.96800   Melbourne
# 1     Bahrain International Circuit  26.0325   50.51060      Sakhir
# 2    Circuit de Barcelona-Catalunya  41.5700    2.26111    Montmeló
# 3                    Hockenheimring  49.3278    8.56583  Hockenheim
# 4                       Hungaroring  47.5789   19.24860    Budapest
# ..                              ...      ...        ...         ...
# 250    Circuit de Spa-Francorchamps  50.4372    5.97139         Spa
# 251                  Suzuka Circuit  34.8431  136.54100      Suzuka
# 252       Circuit Gilles Villeneuve  45.5000  -73.52280    Montreal
# 253              Yas Marina Circuit  24.4672   54.60310   Abu Dhabi
# 254          Circuit Park Zandvoort  52.3888    4.54092   Zandvoort
#
#          country
# 0      Australia
# 1        Bahrain
# 2          Spain
# 3        Germany
# 4        Hungary
# ..           ...
# 250      Belgium
# 251        Japan
# 252       Canada
# 253          UAE
# 254  Netherlands
#
# [255 rows x 7 columns]

# %%
pd.DataFrame(circuits).to_csv('circuits.csv', index = False)

# %%
#Diccionario calificaciones
qualifyings = {'raceName':[], 'driverId':[], 'constructorId':[], 'number':[], 'position':[], 'Q1':[], 'Q2':[], 'Q3':[]}

# %%
for year in list (range(2010, 2023)):
    url = "http://ergast.com/api/f1/{}/qualifying.json"
    response = requests.get(url.format(year))
    content = json.loads(response.content)
    
    
    for item in content['MRData']['RaceTable']['Races']:
        for item2 in item['QualifyingResults']:
            qualifyings['raceName'].append(item['raceName'])
            qualifyings['driverId'].append(item2['Driver']['driverId'])
            qualifyings['constructorId'].append(item2['Constructor']['constructorId'])
            qualifyings['number'].append(int(item2['number']))
            qualifyings['position'].append(int(item2['position']))
            try:
                qualifyings['Q1'].append(item2['Q1'])
            except:
                qualifyings['Q1'].append(np.nan)
            try:
                qualifyings['Q2'].append(item2['Q2'])
            except:
                qualifyings['Q2'].append(np.nan)
            try:
                qualifyings['Q3'].append(item2['Q3'])
            except:
                qualifyings['Q3'].append(np.nan)

# %%
pd.DataFrame(qualifyings).to_csv('qualifyings.csv', index = False)

# %%
pd.DataFrame(qualifyings)
# Out:
#                      raceName         driverId constructorId  number  \
# 0          Bahrain Grand Prix           vettel      red_bull       5
# 1          Bahrain Grand Prix            massa       ferrari       7
# 2          Bahrain Grand Prix           alonso       ferrari       8
# 3          Bahrain Grand Prix         hamilton       mclaren       2
# 4          Bahrain Grand Prix          rosberg      mercedes       4
# ..                        ...              ...           ...     ...
# 385  Saudi Arabian Grand Prix          russell      mercedes      63
# 386  Saudi Arabian Grand Prix           alonso        alpine      14
# 387  Saudi Arabian Grand Prix           bottas          alfa      77
# 388  Saudi Arabian Grand Prix            gasly    alphatauri      10
# 389  Saudi Arabian Grand Prix  kevin_magnussen          haas      20
#
#      position        Q1        Q2        Q3
# 0           1  1:55.029  1:53.883  1:54.101
# 1           2  1:55.313  1:54.331  1:54.242
# 2           3  1:54.612  1:54.172  1:54.608
# 3           4  1:55.341  1:54.707  1:55.217
# 4           5  1:55.463  1:54.682  1:55.241
# ..        ...       ...       ...       ...
# 385         6  1:29.680  1:29.618  1:29.104
# 386         7  1:29.978  1:29.295  1:29.147
# 387         8  1:29.683  1:29.404  1:29.183
# 388         9  1:29.891  1:29.418  1:29.254
# 389        10  1:29.831  1:29.546  1:29.588
#
# [390 rows x 8 columns]
